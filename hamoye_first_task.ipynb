# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd Desktop/
# Out:
# C:\Users\ADENIYI\Desktop

# %%
df = pd.read_csv('./FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding="latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
for i, value in enumerate(df['Element'].unique()):
    print(i, value)
# Out:
# 0 Total Population - Both sexes
# 1 Domestic supply quantity
# 2 Food supply (kcal/capita/day)
# 3 Protein supply quantity (g/capita/day)
# 4 Fat supply quantity (g/capita/day)
# 5 Production
# 6 Import Quantity
# 7 Stock Variation
# 8 Export Quantity
# 9 Feed
# 10 Seed
# 11 Losses
# 12 Processing
# 13 Other uses (non-food)
# 14 Residuals
# 15 Food
# 16 Food supply quantity (kg/capita/yr)
# 17 Tourist consumption

# %% [markdown]
# ## Question 1

# %%
df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %% [markdown]
# ## Question 2

# %%
df.shape
# Out:
# (60943, 12)

# %% [markdown]
# ## Question 3

# %%
df.Area.nunique()
# Out:
# 49

# %% [markdown]
# ## Question 5

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# ## Question 12

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ## Question 6

# %%
df.groupby('Element').sum()['Y2017']
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %% [markdown]
# ## Question 13

# %%
missing_2014= sum(df.Y2014.isnull())
missing_2014
# Out:
# 1589

# %% [markdown]
# ## Question 18

# %%
df.Y2017.describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %% [markdown]
# ## Question 19

# %%
madagascar =df[df['Area']=='Madagascar']
madagascar_protein = madagascar[madagascar["Element"]=='Protein supply quantity (g/capita/day)']
madagascar_protein.Y2015.sum()
# Out:
# 173.04999999999998

# %% [markdown]
# ## Question 14

# %%
area_2017= df[["Y2017", "Area"]]
area_2017= area_2017.groupby(['Area']).sum().reset_index()

max_y =area_2017.Y2017.max()
area_2017[area_2017.Y2017== max_y]
# Out:
#        Area       Y2017
# 34  Nigeria  1483268.23

# %% [markdown]
# ## Question 9

# %%
area_2017 = area_2017[['Y2017', 'Area']]
area_2017.sort_values(by= 'Y2017')
# Out:
#          Y2017                         Area
# 42        0.00               Sudan (former)
# 16        0.00                 Ethiopia PDR
# 9        59.84                      Comoros
# 38      442.34                   Seychelles
# 36    12662.63        Sao Tome and Principe
# 5     14650.74                   Cabo Verde
# 21    19102.77                Guinea-Bissau
# 23    21267.96                      Lesotho
# 3     22101.30                     Botswana
# 12    22729.91                     Djibouti
# 18    23154.18                       Gambia
# 17    27979.64                        Gabon
# 24    29342.20                      Liberia
# 32    29874.89                      Namibia
# 7     29937.00     Central African Republic
# 10    41181.68                        Congo
# 43    49841.88                         Togo
# 29    51114.83                    Mauritius
# 14    54343.33                     Eswatini
# 39    55311.33                 Sierra Leone
# ...
